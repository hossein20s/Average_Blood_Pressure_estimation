# %% [markdown]
# <a href="https://colab.research.google.com/github/hossein20s/PPG2bloodPressure/blob/master/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
REPO_NAME = 'PPG2bloodPressure'
# %run gdrive/My\ Drive/lib/connect.ipynb
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Vesion:1.4
# mkdir: cannot create directory ‘/content/gdrive/My Drive/src/’: File exists
# fatal: destination path 'clinicalBERT' already exists and is not an empty directory.

# %%
BUCKET_DIR = 'gs://medicalblockchain_dev'
# !gsutil cp $BUCKET_DIR/data/BP_PPG_ECG/Part_1.mat /tmp/data1.mat
# Out:
# Copying gs://medicalblockchain_dev/data/BP_PPG_ECG/Part_1.mat...
# / [1 files][811.9 MiB/811.9 MiB]   84.5 MiB/s
# Operation completed over 1 objects/811.9 MiB.

# %%
#This part doesnt work
from scipy.io import loadmat
DATA_DIR = BUCKET_DIR + '/data/BP_PPG_ECG/' 
x = loadmat(DATA_DIR + 'Part_1.mat')

# %% [markdown]
# Some data can also be found here. No Idea the realtionship
# https://drive.google.com/drive/u/0/mobile/folders/154j5jxudI3PAvPDjPiscs-P3Q5ZRpq5t?usp=drive_open
#
# Maybe figure it out from
# https://sites.google.com/view/cufflessbp/dataset?authuser=0

# %%
import h5py
import numpy as np

with h5py.File('/tmp/data1.mat', 'r') as f:
  print(list(f.keys()))
  ds = f['Part_1']
  print(ds.shape)
  x = ds[0][0]
  #print(x.dtype)
  print(f[x].shape)
  print(f[x].dtype)
  ppg_abp_ecg = f[x][:]
  print(ppg_abp_ecg.shape)
# Out:
# ['#refs#', 'Part_1']
# (3000, 1)
# (61000, 3)
# float64
# (61000, 3)

# %%
  print(ppg_abp_ecg)
  ppg = ppg_abp_ecg[:,0]
  abp = ppg_abp_ecg[:,1]
  ecg = ppg_abp_ecg[:,2]
  
  import numpy as np
  n = 300
  x = np.arange(n)
  
  import matplotlib.pyplot as plt
  plt.plot(x, ppg[i:i+n], 'y')
  plt.show()
  plt.plot(x, abp[i:i+n], 'b')
  plt.show()
  plt.plot(x, ecg[i:i+n], 'g')
  plt.show()

  n = 300
  i = 0
  plt.plot(ppg[i:i+n], abp[i:i+n], 'y')
  plt.show()
  plt.plot(ecg[i:i+n], abp[i:i+n], 'g')
  plt.show()
  plt.plot(ecg[i:i+n], ppg[i:i+n], 'o')
  plt.show()

  n = 1000
  plt.plot(ppg[i:i+n], abp[i:i+n], 'y')
  plt.show()
  n = 4000
  plt.plot(ppg[i:i+n], abp[i:i+n], 'y')
  plt.show()
  n = 20000
  plt.plot(ppg[i:i+n], abp[i:i+n], 'y')
  n = 300
  i = 1000
  plt.plot(ppg[i:i+n], abp[i:i+n], 'y')
  plt.show()
  i = 10000
  plt.plot(ppg[i:i+n], abp[i:i+n], 'y')
  plt.show()
  plt.plot(ecg[i:i+n], abp[i:i+n], 'g')
  plt.show()
  i = 20000
  plt.plot(ppg[i:i+n], abp[i:i+n], 'y')
  plt.show()



# red dashes, blue squares and green triangles
#plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
# Out:
# [[ 1.75953079e+00  6.70629552e+01 -6.06060606e-02]
#  [ 1.71847507e+00  6.93586281e+01 -7.52688172e-02]
#  [ 1.68426197e+00  7.53664529e+01 -7.03812317e-02]
#  ...
#  [ 1.64418377e+00  7.64410232e+01 -1.00195503e-01]
#  [ 1.60019550e+00  8.18138747e+01 -9.04203324e-02]
#  [ 1.56598240e+00  9.13873191e+01 -4.54545455e-02]]

# %%
import pandas as pd
dataFile = '/tmp/data1.mat'
data = pd.read_hdf(dataFile)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-0d01c23df92b> in <module>()
#       1 import pandas as pd
#       2 dataFile = '/tmp/data1.mat'
# ----> 3 data = pd.read_hdf(dataFile)
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/pytables.py in read_hdf(path_or_buf, key, mode, **kwargs)
#     375             groups = store.groups()
#     376             if len(groups) == 0:
# --> 377                 raise ValueError('No dataset in HDF5 file.')
#     378             candidate_only_group = groups[0]
#     379
#
# ValueError: No dataset in HDF5 file.
